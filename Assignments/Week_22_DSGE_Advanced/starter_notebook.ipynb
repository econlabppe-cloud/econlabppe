# %% [markdown]
# # 💻 תרגול מעשי - בהצלחה!
# כאן תוכלו לכתוב ולהריץ את הקוד שלכם. אל תשכחו לשמור עותק בגיטהאב שלכם כשתסיימו!

# %%
print("אני מבין שאתה רוצה ליצור מאקרו באקסל. חשוב לי להבהיר שגוגל קולאב מיועד בעיקר לכתיבת והרצת קוד בפייתון (או בשפות כמו R ו-Swift), ולא תומך ישירות בכתיבת או הרצת קוד VBA של אקסל. כדי ליצור מאקרו לאקסל, תצטרך לעשות זאת ישירות בתוך אקסל (באמצעות עורך ה-VBA שלו).")
# Out:
# אני מבין שאתה רוצה ליצור מאקרו באקסל. חשוב לי להבהיר שגוגל קולאב מיועד בעיקר לכתיבת והרצת קוד בפייתון (או בשפות כמו R ו-Swift), ולא תומך ישירות בכתיבת או הרצת קוד VBA של אקסל. כדי ליצור מאקרו לאקסל, תצטרך לעשות זאת ישירות בתוך אקסל (באמצעות עורך ה-VBA שלו).
